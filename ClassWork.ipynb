# %%
students = []

for i in range (5):
    name = input("Enter students name: ")
    students.append(name)

print("student name in upper case: ")
for student in students:
    print(student.upper())
# Out:
# Enter students name: Ribu
# Enter students name: rakib
# Enter students name: rahat
# Enter students name: rio
# Enter students name: sopnil
# student name in upper case:
# RIBU
# RAKIB
# RAHAT
# RIO
# SOPNIL

# %%
list4 = [x for x in range(50) if x%2 == 0 if x%5 == 0]
print(list4)
# Out:
# [0, 10, 20, 30, 40]

# %%
list1 = ['kola', 'shopnil', 'priyo', 'honey', 'bunny']
take = input("Enter the selected item to delete: ")

if take in list1:
  list1.remove(take)
print(list1)
# Out:
# Enter the selected item to delete: bunny
# ['kola', 'shopnil', 'priyo', 'honey']

# %%
my_tuple = ("apple", "banana", "cherry", "date", "elderberry", "fig", "grape", "honeydew", "kiwi", "lemon")
take = input("Enter tuple to find Posotion: ")

if take in my_tuple:
  position = my_tuple.index(take)
  print(f"Positon : {position}")
else:
  print(f"not found")
# Out:
# Enter tuple to find Posotion: grape
# Positon : 6
