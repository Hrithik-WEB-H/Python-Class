# %%
num1 = float(input("First number: "))
num2 = float(input("Second number:"))

add = num1 + num2
sub = num1 - num2
mult = num1 * num2
div = num1 / num2
mod = num2 % num2

print(f"Addition: {add}")
print(f"Subtraction: {sub}")
print(f"Multiplication: {mult}")
print(f"Division: {div}")
print(f"Modulus: {mod}")
# Out:
# First number: 10
# Second number:5
# Addition: 15.0
# Subtraction: 5.0
# Multiplication: 50.0
# Division: 2.0
# Modulus: 0.0

# %%
num1 = float(input("First number: "))
if num1%2 == 0:
  print(f"{num1} is even")
else:
    print(f"{num1} is odd")
# Out:
# First number: 10
# 10.0 is even

# %%
import cmath
a = float(input("Num 1: "))
b = float(input("Num 2:"))
c = float(input("Num 3:"))

d = (b**2) - (4*a*c)
sol1 = (-b + cmath.sqrt(d))/(2*a)
sol2 = (-b - cmath.sqrt(d))/(2*a)

print(f"Solution 1: {sol1}")
print(f"Solution 2: {sol2}")
# Out:
# Num 1: 10
# Num 2:20
# Num 3:30
# Solution 1: (-1+1.4142135623730951j)
# Solution 2: (-1-1.4142135623730951j)

# %%
num1 = float(input("Enter 1st num:"))
num2 = float(input("Enter 2nd num:"))

if num1 > num2:
  print(f"The greater number is {num1}")
else:
 print(f"The number is {num2}")
# Out:
# Enter 1st num:20
# Enter 2nd num:10
# The greater number is 20.0

# %%
a = 0
b = 1

print(a & b )
print(a or b)
# Out:
# 0
# 1

# %%
from os import uname


uName = input("Enter user name: ")
passwd = int(input("Enter pass: "))

if uName == "@Rittik" and passwd == 1234:
  print(f"Valid user {uName}")
else:
  print(f"Invalid user Unknown")
# Out:
# Enter user name: @Rittik
# Enter pass: 1234
# Valid user @Rittik
