# %%
Movies = ["Spyder Man", "Gldiator", "Gladiator 2", "Maharaja", "Munjumel boys"]
print(f"Second Movie: {Movies[1]}")

Movies.append("Kelor Kirti")
print(Movies)

remove = Movies.pop(0)
print(Movies)
# Out:
# Second Movie: Gldiator
# ['Spyder Man', 'Gldiator', 'Gladiator 2', 'Maharaja', 'Munjumel boys', 'Kelor Kirti']
# ['Gldiator', 'Gladiator 2', 'Maharaja', 'Munjumel boys', 'Kelor Kirti']

# %%
a = 10
b = -5
c = a + b
print(c)
# Out:
# 5

# %%
pi = 301416
radius = 0.5
area = pi * (radius**2)
print(area)
# Out:
# 75354.0

# %%
name = "Alice"
greeting = f"Hello, {name}"
print(greeting)
# Out:
# Hello, Alice

# %%
is_valid = True
if is_valid:
  print("The data is valid.")
# Out:
# The data is valid.

# %%
result = None
if result is None:
  print("No result avaliable")
# Out:
# No result avaliable

# %%
text = "PYthon Programming"
first_letter = text[0]
substring =text[7:18]
print(first_letter)
print(substring)
# Out:
# P
# Programming

# %%
text = "Hello world"
upper_text = text.upper()
replaced_text = text.replace("World", "Python")
print(upper_text)
print(replaced_text)
# Out:
# HELLO WORLD
# Hello world

# %%
fruits = ["apple", "babanana", "cherry"]
first_fruit = fruits[0]
print(first_fruit)
# Out:
# apple

# %%
fruits.append("orange")
fruits.remove("babanana")
print(fruits)
# Out:
# ['apple', 'cherry', 'orange']

# %%
squares = [x**2 for x in range(5)]
print(squares)
# Out:
# [0, 1, 4, 9, 16]

# %%
cordinates = (10, 20)
x = cordinates[0]
print(x)
# Out:
# 10

# %%
cordinates = (10, 20)
print(cordinates)
# Out:
# (10, 20)

# %%
student = {"name": "alice","age": 21, "grade": "A"}
name = student["name"]
print(name)
# Out:
# alice

# %%
student["age"] = 22
del student["grade"]

# %%
book = {"title": "C++", "author": "Jone hamber","year": 1992, "genre": "ABC"}
print("Title:", book["title"])

c_year = 2024
book["year"] = c_year

print(book)
# Out:
# Title: C++
# {'title': 'C++', 'author': 'Jone hamber', 'year': 2024, 'genre': 'ABC'}

# %%
tupple = ["Rittik", 69, 6.9]
String, intger, float_ = tupple

print(f"String: {String}")
print(f"Integer: {intger}")
print(f"Float: {float_}")
# Out:
# String: Rittik
# Integer: 69
# Float: 6.9

# %%
set_A = {1, 2, 3, 4, 5}
set_B = {4, 5, 6, 7, 8}

u = set_A | set_B
intersection = set_A & set_B
u = u - intersection

print(u)
# Out:
# {1, 2, 3, 6, 7, 8}
